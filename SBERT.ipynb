# %% [markdown]
# <a href="https://colab.research.google.com/github/inigo-rojo/colab/blob/main/SBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# instalacion y ejemplo de sbert web

# %%
pip install -U sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 79 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 31.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 46.3 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 880 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 28.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.8 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=7e8b58e7930fed49ef5af9c14bc6211ad302efa0bba3d370a9985a7d04fef209
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=66fbd0820c72ada96b623505ddbc46f8bee4d46f3799390836b52b7d042cf785
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# ...

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# Two lists of sentences
sentences1 = ['The cat sits outside',
             'A man is playing guitar',
             'The new movie is awesome']

sentences2 = ['The dog plays in the garden',
              'A woman watches TV',
              'The new movie is so great']

#Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarits
cosine_scores = util.cos_sim(embeddings1, embeddings2)

#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i]))
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# The cat sits outside 		 The dog plays in the garden 		 Score: 0.2838
# A man is playing guitar 		 A woman watches TV 		 Score: -0.0327
# ...

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# Single list of sentences
sentences = ['The cat sits outside',
             'A man is playing guitar',
             'I love pasta',
             'The new movie is awesome',
             'The cat plays in the garden',
             'A woman watches TV',
             'The new movie is so great',
             'Do you like pizza?']

#Compute embeddings
embeddings = model.encode(sentences, convert_to_tensor=True)

#Compute cosine-similarities for each sentence with each other sentence
cosine_scores = util.cos_sim(embeddings, embeddings)

#Find the pairs with the highest cosine similarity scores
pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

#Sort scores in decreasing order
pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)

for pair in pairs[0:10]:
    i, j = pair['index']
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences[i], sentences[j], pair['score']))
# Out:
# The new movie is awesome 		 The new movie is so great 		 Score: 0.8939
# The cat sits outside 		 The cat plays in the garden 		 Score: 0.6788
# I love pasta 		 Do you like pizza? 		 Score: 0.5096
# I love pasta 		 The new movie is so great 		 Score: 0.2560
# I love pasta 		 The new movie is awesome 		 Score: 0.2440
# A man is playing guitar 		 The cat plays in the garden 		 Score: 0.2105
# The new movie is awesome 		 Do you like pizza? 		 Score: 0.1969
# The new movie is so great 		 Do you like pizza? 		 Score: 0.1692
# The cat sits outside 		 A woman watches TV 		 Score: 0.1310
# The cat plays in the garden 		 Do you like pizza? 		 Score: 0.0900

# %%
prueba castellano

# %%
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# Single list of sentences
sentences = ['Hay una puerta abierta',
             'hay un armario abierto',
             'el coche es rojo',
             'el autobus es verde',
             'un niño ve la television',
             'un joven conduce un coche',
             'han abierto una carniceria en el barrio',
             'te gusta la carne?']

#Compute embeddings
embeddings = model.encode(sentences, convert_to_tensor=True)

#Compute cosine-similarities for each sentence with each other sentence
cosine_scores = util.cos_sim(embeddings, embeddings)

#Find the pairs with the highest cosine similarity scores
pairs = []
for i in range(len(cosine_scores)-1):
    for j in range(i+1, len(cosine_scores)):
        pairs.append({'index': [i, j], 'score': cosine_scores[i][j]})

#Sort scores in decreasing order
pairs = sorted(pairs, key=lambda x: x['score'], reverse=True)

for pair in pairs[0:10]:
    i, j = pair['index']
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences[i], sentences[j], pair['score']))
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/556 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/452 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Hay una puerta abierta 		 hay un armario abierto 		 Score: 0.7087
# hay un armario abierto 		 han abierto una carniceria en el barrio 		 Score: 0.5918
# ...

# %% [markdown]
# prueba del dataset stsb_multi_mt en ingles y castellano

# %%
# install datasets
# !pip install datasets

# Make sure that we have a recent version of pyarrow in the session before we continue - otherwise reboot Colab to activate it
import pyarrow
if int(pyarrow.__version__.split('.')[1]) < 16 and int(pyarrow.__version__.split('.')[0]) == 0:
    import os
    os.kill(os.getpid(), 9)

from datasets import list_datasets, list_metrics, load_dataset, load_metric
# Out:
# ...
# Generating dev split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Dataset stsb_multi_mt downloaded and prepared to /root/.cache/huggingface/datasets/stsb_multi_mt/en/1.0.0/a5d260e4b7aa82d1ab7379523a005a366d9b124c76a5a5cf0c4c5365458b0ba9. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
datasetEN = load_dataset("stsb_multi_mt",'en')
datasetES = load_dataset("stsb_multi_mt",'es')
# Out:
# Reusing dataset stsb_multi_mt (/root/.cache/huggingface/datasets/stsb_multi_mt/en/1.0.0/a5d260e4b7aa82d1ab7379523a005a366d9b124c76a5a5cf0c4c5365458b0ba9)
# ...
# Generating dev split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Dataset stsb_multi_mt downloaded and prepared to /root/.cache/huggingface/datasets/stsb_multi_mt/es/1.0.0/a5d260e4b7aa82d1ab7379523a005a366d9b124c76a5a5cf0c4c5365458b0ba9. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
print(datasetEN)
print(datasetEN['train'])
print(datasetEN['train']['sentence1'])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 5749
#     })
#     test: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 1379
#     })
#     dev: Dataset({
#         features: ['sentence1', 'sentence2', 'similarity_score'],
#         num_rows: 1500
#     })
# })
# Dataset({
#     features: ['sentence1', 'sentence2', 'similarity_score'],
#     num_rows: 5749
# })
# ...

# %% [markdown]
# evaluar EN

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# Two lists of sentences
sentences1 = datasetEN['train']['sentence1']

sentences2 = datasetEN['train']['sentence2']

#Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarits
cosine_scores = util.cos_sim(embeddings1, embeddings2)  * 5 #para comparar con similarity_score del dataset

# %%
#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f} \t\t Score(dataset): {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i], datasetEN['train']['similarity_score'][i]))
    if(i > 100):
      break
# Out:
# A plane is taking off. 		 An air plane is taking off. 		 Score: 4.6965 		 Score(dataset): 5.0000
# A man is playing a large flute. 		 A man is playing a flute. 		 Score: 4.5102 		 Score(dataset): 3.8000
# A man is spreading shreded cheese on a pizza. 		 A man is spreading shredded cheese on an uncooked pizza. 		 Score: 4.4600 		 Score(dataset): 3.8000
# Three men are playing chess. 		 Two men are playing chess. 		 Score: 3.9728 		 Score(dataset): 2.6000
# A man is playing the cello. 		 A man seated is playing the cello. 		 Score: 4.6433 		 Score(dataset): 4.2500
# Some men are fighting. 		 Two men are fighting. 		 Score: 4.4599 		 Score(dataset): 4.2500
# A man is smoking. 		 A man is skating. 		 Score: 1.6638 		 Score(dataset): 0.5000
# The man is playing the piano. 		 The man is playing the guitar. 		 Score: 2.3026 		 Score(dataset): 1.6000
# A man is playing on a guitar and singing. 		 A woman is playing an acoustic guitar and singing. 		 Score: 3.1769 		 Score(dataset): 2.2000
# ...

# %% [markdown]
# evaluar ES

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# Two lists of sentences
sentences1 = datasetES['train']['sentence1']

sentences2 = datasetES['train']['sentence2']

#Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarits
cosine_scores = util.cos_sim(embeddings1, embeddings2) * 5 #para comparar con similarity_score del dataset

# %%
#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f} \t\t Score(dataset): {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i], datasetES['train']['similarity_score'][i]))
    if(i > 100):
      break
# Out:
# Un avión está despegando. 		 Un avión está despegando. 		 Score: 5.0000 		 Score(dataset): 5.0000
# Un hombre está tocando una gran flauta. 		 Un hombre está tocando una flauta. 		 Score: 4.6886 		 Score(dataset): 3.8000
# Un hombre está untando queso rallado en una pizza. 		 Un hombre está untando queso rallado en una pizza cruda. 		 Score: 4.7548 		 Score(dataset): 3.8000
# Tres hombres están jugando al ajedrez. 		 Dos hombres están jugando al ajedrez. 		 Score: 4.8632 		 Score(dataset): 2.6000
# Un hombre está tocando el violonchelo. 		 Un hombre sentado está tocando el violonchelo. 		 Score: 4.8289 		 Score(dataset): 4.2500
# Algunos hombres están luchando. 		 Dos hombres están luchando. 		 Score: 4.5894 		 Score(dataset): 4.2500
# Un hombre está fumando. 		 Un hombre está patinando. 		 Score: 3.9548 		 Score(dataset): 0.5000
# El hombre está tocando el piano. 		 El hombre está tocando la guitarra. 		 Score: 4.1722 		 Score(dataset): 1.6000
# ...

# %%
Entrenar red para el dataset EN y ES

# %% [markdown]
# Trabajar en EN-EN con el dataset https://alt.qcri.org/semeval2016/task2/

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# cargar chunks gold standard(fallo algo en la anidacion)

# %%
import copy
f = open("/content/drive/My Drive/TFG/ISTSdatabase/train_2015_10_22.utf-8/STSint.input.headlines.sent1.chunk.txt", "r")
chunks1=[]
for x in f:
  y = x.split(']')
  chunks1sub = []
  for z in y:
    chunks1sub.append(str(z).replace('[','').strip())
  chunks1.append(copy.deepcopy(chunks1sub))
  print(chunks1[0])
  print(x)
f.close
# Out:
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ Former Nazi death camp guard Demjanjuk ] [ dead ] [ at 91 ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ Saudis ] [ to permit ] [ women ] [ to compete ] [ in Olympics ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ US drone strike ] [ kills ] [ 5 militants ] [ in Pakistan ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ Syria peace plan conditions ] [ " ] [ unacceptable ] [ , ] [ " ] [ opposition ] [ says ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ Syrian regime ] [ denies ] [ role ] [ in Houla massacre ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ China stocks ] [ close ] [ mixed ] [ Friday ]
#
# ['Former Nazi death camp guard Demjanjuk', 'dead', 'at 91', '']
# [ Mall attackers ] [ used ] [ ` less is more ' strategy ]
#
# ...

# %%
from sentence_transformers import SentenceTransformer, util
f = open("/content/drive/My Drive/TFG/ISTSdatabase/train_2015_10_22.utf-8/STSint.input.headlines.sent1.txt", "r")
sentences1=[]
for x in f:
  sentences1.append(x)
f.close
f = open("/content/drive/My Drive/TFG/ISTSdatabase/train_2015_10_22.utf-8/STSint.input.headlines.sent2.txt", "r")
sentences2=[]
for x in f:
  sentences2.append(x)
f.close


model = SentenceTransformer('all-MiniLM-L6-v2')

#Compute embedding for both lists
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

#Compute cosine-similarities
cosine_scores = util.cos_sim(embeddings1, embeddings2)

#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i]))
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Former Nazi death camp guard Demjanjuk dead at 91
#  		 John Demjanjuk , convicted Nazi death camp guard , dies aged 91
#  		 Score: 0.8924
# ...
